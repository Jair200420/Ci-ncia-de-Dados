# %% [markdown]
# # Exercício 1

# %% [markdown]
# Crie uma classe `Cliente` para um e-commerce que armazene o nome do cliente, seu email e compras realizadas (uma lista de valores, inicializada vazia - não é parâmetro do método de inicialização). A classe deve ter métodos para adicionar uma nova compra e calcular o total gasto.

# %%
import numpy as np

# %%
class Cliente:
    def __init__(self, cliente, email):
        self.cliente = cliente
        self.email = email
        self.compras = []

    def adicionar_compras(self, valor):
            self.compras.append(valor)

    def total_gasto(self):
            return sum(self.compras)

# %%
cliente1 = Cliente("J", "jgan@gmail.com")

# %%
cliente1.email
# Out:
# 'jgan@gmail.com'

# %%
cliente1.adicionar_compras(50)

# %%
cliente1.compras
# Out:
# [50]

# %% [markdown]
# # Exercício 2

# %% [markdown]
# Crie uma classe `AnaliseVendas` que armazene os dados de vendas mensais (uma lista de números, inicializada vazia - não é parâmetro do método de inicialização). A classe deve ter métodos para adicionar vendas, calcular a média de vendas e encontrar o mês com a maior venda.

# %%
class AnaliseVendas:
    def __init__(self):
        self.vendas_mensais = []
    
    def adicionar_vendas(self, valor):
        self.vendas_mensais.append(valor)

    def media_vendas(self):
        media = np.mean(self.vendas_mensais)
        maior_venda = max(self.vendas_mensais)
        return  media, maior_venda

# %%
vendas = AnaliseVendas()

# %%
vendas.adicionar_vendas(142)
vendas.adicionar_vendas(58741)
vendas.adicionar_vendas(1254)
vendas.adicionar_vendas(54568)
vendas.adicionar_vendas(2)

# %%
vendas.media_vendas()
# Out:
# (22941.4, 58741)
