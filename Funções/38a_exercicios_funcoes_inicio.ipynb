# %% [markdown]
# # Exercício 1

# %% [markdown]
# Escreva uma função `aumento_salarial` que recebe o salário atual de um funcionário e a porcentagem de aumento, retornando o novo salário.

# %%
def aumento_salarial (salario_base):
    """
    Calcula o valor do aumento no salário base

    Parameters
    ----------
    salario_base : float
        Salário original do funcionário

    Retruns
    -------
    tuple : (float, float)
        Valor do salário com aumento, Valor do aumento
    """    
    aumento_valor = salario_base * 0.15
    salario_aumento = salario_base + aumento_valor
    return salario_aumento, aumento_valor

# %%
salario = 1000
novo_salario, aumento = aumento_salarial(salario)

print(f"O seu sálrio com um aumento de 15% é: R$ {novo_salario:.2f}. O aumento líquido foi de: R$ {aumento:.2f}")
# Out:
# O seu sálrio com um aumento de 15% é: R$ 1150.00. O aumento líquido foi de: R$ 150.00

# %% [markdown]
# # Exercício 2

# %% [markdown]
#  Crie uma função `normalizar_numeros` que recebe uma lista de números e retorna uma nova lista com os valores normalizados entre 0 e 1.

# %%
def normalizar_numeros (numeros):
    """
    Normaliza uma lista de números para o intervalo [0, 1]

    Parameters
    ----------
    lista de números
    
    Retruns
    -------
    list de float
        Itens normalizados
    """
    min_val = min(numeros)
    max_val = max(numeros)
    return [(numero - min_val)/(max_val - min_val) for numero in numeros]

print(normalizar_numeros([1, 2, 3, 4]))
# Out:
# [0.0, 0.3333333333333333, 0.6666666666666666, 1.0]

# %% [markdown]
# # Exercício 3

# %% [markdown]
# Escreva uma função gerar_email_corporativo que recebe um nome completo e retorna um email no formato "nome.ultimonome@empresa.com".

# %%
def gerar_email_corporativo (nome_completo):
    """
    Gera um email da empresa, baseado no sue primeiro e último nome

    Parameters
    ----------
    Nome completo

    Retruns
    -------
    String
    """
    partes_nome = nome_completo.split()
    email = f"{partes_nome[0]}.{partes_nome[-1]}@empresa.com"
    return email.lower()

exemplo = "Jair Guimarães de Araujo Neto"
gerar_email_corporativo(exemplo)
# Out:
# 'jair.neto@empresa.com'

# %% [markdown]
# # Exercício 4

# %% [markdown]
# Dada uma lista de valores de compras dos clientes, escreva uma função `segmentar_clientes` que classifica cada cliente como 'alto', 'médio' ou 'baixo' valor de compra, baseando-se em limites predefinidos para as segmentações e retorne uma lista de segmentações correspondentes. Assume-se que 'alto' é acima de 500, 'médio' entre 200 e 500, e 'baixo' abaixo de 200.

# %%
compras = [100, 250, 550, 150, 450]

# %%
def segmentar_clientes (valores_compras):
    """
    Segmenta valores entre baixo, médio ou alto, a depender do valor

    Parameters
    ----------
    List (float)

    Rerurns
    -------
    Valores segmentados e sua definição de baixo, médio ou alto
    """
    segmentos = []
    for valor in valores_compras:
        if valor > 500:
            segmentos.append("alto")
        elif valor > 200:
            segmentos.append("médio")
        else:
            segmentos.append("baixo")
    return segmentos

print(segmentar_clientes(compras))
# Out:
# ['baixo', 'médio', 'alto', 'baixo', 'médio']

# %% [markdown]
# # Exercício 5

# %% [markdown]
# Crie uma função `verifica_email` que recebe um email e retorna um booleano a depender se o email tem ou não o domínio "@empresa.com".
#
# Aplique a função para cada email da lista `emails` e retorne a lista de booleanos correspondentes.

# %%
emails = ['joao@empresa.com', 'maria@mail.com', 'jose@empresa.com', 'andre@abc.com']

# %%
emails = ['joao@empresa.com', 'maria@mail.com', 'jose@empresa.com', 'andre@abc.com']


def verifica_email(email):
    """Verifica se um e-mail é corporativo ou não (termina com '@empresa.com').

    Parameters
    ----------
    email : str
        E-mail a ser verificado.

    Returns
    -------
    bool
        True se o e-mail é corporativo, False caso contrário.
    """
    return email.endswith('@empresa.com')

# %%
for email in emails:
    print(verifica_email(email))
# Out:
# True
# False
# True
# False
