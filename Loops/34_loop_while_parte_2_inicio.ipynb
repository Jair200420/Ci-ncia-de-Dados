# %% [markdown]
# ## Exemplo 1

# %% [markdown]
# Uma empresa deseja monitorar se a meta de vendas mensal de `R$50.000` foi alcançada. À medida que as vendas são registradas, a partir de input do usuário, o sistema deve atualizar e verificar se a meta foi atingida.

# %%
meta_vendas = 50_000

# %%
vendas_atual = 0

while vendas_atual < meta_vendas:
    nova_venda = float(input("Digite o valor da nova venda"))
    vendas_atual += nova_venda
    print(f"Total de vendas atual: R$ {vendas_atual}")

print("Meta de vendas alcançada!")
# Out:
# Total de vendas atual: R$ 500.0
# Total de vendas atual: R$ 3000.0
# Total de vendas atual: R$ 28000.0
# Total de vendas atual: R$ 53000.0
# Meta de vendas alcançada!

# %% [markdown]
# ## Exemplo 2

# %% [markdown]
# Em um sistema empresarial, o acesso a uma área restrita exige a inserção de uma senha correta. O usuário tem 3 tentativas para inserir a senha corretamente.

# %%
senha_correta = "acesso2024"
tentativas = 3

while tentativas > 0:
    senha = input("Digite a senha corretamente: ")
    if senha == senha_correta:
        print("Senha correta!")
        break
    else:
        tentativas -= 1
        print(f"Senha incorreta... você ainda tem {tentativas} tentativa(s) restante(s).")
# Out:
# Senha correta!
