# %% [markdown]
# # Biblioteca padrão do Python

# %% [markdown]
# ## Exemplo com `datetime`
#
# O módulo `datetime` fornece classes para manipulação de datas e horas de forma simples.

# %%
import datetime

# %%
# Obter data e hora:

agora = datetime.datetime.now()
print(agora)
# Out:
# 2026-03-17 15:25:03.904330

# %%
# Criar data específica:

data_nascimento = datetime.datetime(2000, 4, 20)
print(f"Data de nascimento: {data_nascimento.strftime('%d/%m/%Y')}")
# Out:
# Data de nascimento: 20/04/2000

# %% [markdown]
# ## Exemplo com `random`
#
# O módulo `random` é usado para gerar números aleatórios e realizar escolhas aleatórias.

# %%
import random

# %%
# Gerar um número aleatório entre 1 e 10:

numero_aleatorio = random.randint(1, 10)
print(f"Um número aleatório entre 1 e 10: {numero_aleatorio}")
# Out:
# Um número aleatório entre 1 e 10: 3

# %%
# Escolher aleatoriamente a partir de uma lista:

cores = ["red", "green", "blue", "black", "white", "gray"]
cor_escolhida = random.choice(cores)
print(f"Cor escolhida: {cor_escolhida}")
# Out:
# Cor escolhida: gray

# %% [markdown]
# ## Exemplo com `os`
#
# O módulo `os` fornece uma maneira portátil de usar funcionalidades dependentes do sistema operacional, como percorrer diretórios ou manipular caminhos de arquivos.

# %%
import os

# %%
# Obter diretório de trabalho atual:

diretorio_atual = os.getcwd()
print(f"Diretório de trabalho atual: {diretorio_atual}")
# Out:
# Diretório de trabalho atual: c:\Users\Jair Neto\Desktop\Certificados\Ciência de Dados\Módulos

# %%
# Listando arquivos em um diretório:

for arquivo in os.listdir(diretorio_atual):
    print(arquivo)
# Out:
# 43_modulos_inicio.ipynb
# 44_modulos_biblioteca_padrao_inicio.ipynb
# meu_modulo.py
# __pycache__

# %% [markdown]
# ## Mais exemplos
#
# https://docs.python.org/3/library/index.html
