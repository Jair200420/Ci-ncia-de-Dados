# %% [markdown]
# # Principais operações

# %%
2 + 6
# Out:
# 8

# %%
2 * 7
# Out:
# 14

# %%
5 - 2
# Out:
# 3

# %%
2**10
# Out:
# 1024

# %%
10 / 5 # Resultado será "float"
# Out:
# 2.0

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
# Representando potências de 10:

1.5 * 10**2
# Out:
# 150.0

# %%
# Representando números grandes:

1.5e20 # O "e" representa potências de 10
# Out:
# 1.5e+20

# %%
1.5e-20
# Out:
# 1.5e-20

# %%
# Facilitando a leitura de grandes números

1_000_000_000
# Out:
# 1000000000

# %% [markdown]
# A utilização de uma número/variável float tende a tornar o resultado float

# %%
# Erro de representação decimal, a partir da conversão do sistema binário da máquina:

0.1 + 0.2

# Possível correção:

(10 + 20) / 100
# Out:
# 0.3

# %% [markdown]
# # Strings

# %%
'Isto é um texto.'
# Out:
# 'Isto é um texto.'

# %%
print("Isto é um texto.")
# Out:
# Isto é um texto.

# %%
"""
Este texto
tem múltiplas
linhas
"""
# Out:
# '\nEste texto\ntem múltiplas\nlinhas\n'

# %%
print("""
Este texto
tem múltiplas
linhas
""")
# Out:
# Este texto
# tem múltiplas
# linhas

# %%
print("Opa, \\n pulei linha")
# Out:
# Opa, \n pulei linha

# %%
print("Olha uma \t tabulação")
# Out:
# Olha uma 	 tabulação
