# %% [markdown]
# # Formatação de strings

# %% [markdown]
# ## f-strings

# %% [markdown]
# Disponíveis a partir do Python 3.6, as f-strings avançaram ainda mais na flexibilidade e na legibilidade. O uso básico é bem simples, bastando colocar `f` (ou `F`) antes da string e a variável entre parênteses:

# %%
nome = "Jair"
f"nome: {nome}"
# Out:
# 'nome: Jair'

# %% [markdown]
# As f-strings são resolvidas em tempo de execução, de forma que podem ser passadas expressões diretamente:

# %%
print(f"Conta: {2 * 5}")
# Out:
# Conta: 10

# %% [markdown]
# ### Lidando com números

# %% [markdown]
# Pode-se adotar a mesma forma de lidar vista com o `format`:

# %%
num = 15.87

print(f"10 caracteres e 4 casas decimais: {num:10.4f}")
# Out:
# 10 caracteres e 4 casas decimais:    15.8700

# %% [markdown]
# ### Alinhamento
#
# O que foi visto sobre alinhamento na parte do `format` continua valendo aqui. E ainda podemos usar a resolução em tempo de execução. Veja o exemplo:

# %%
pessoas = {
    "Jair": {"Nome": "Jair Guimarães", "Idade": 25, "Empresa": "UPE"},
    "Gabriel": {"Nome": "Gabriel Oliveira", "Idade": 25, "Empresa": "Musashi"},
    "Anderson": {"Nome": "Anderson de Deus", "Idade": 39, "Empresa": "Aeroporto"},
}

print(f"{'Nome':^16} | {'Idade':^5} | {'Empresa':^16}")
print(f"{'-' * 42}")
print(f"{pessoas['Jair']['Nome']:^16} | {pessoas['Jair']['Idade']:^5} | {pessoas['Jair']['Empresa']:^16}")
print(f"{pessoas['Gabriel']['Nome']:^16} | {pessoas['Gabriel']['Idade']:^5} | {pessoas['Gabriel']['Empresa']:^16}")
print(f"{pessoas['Anderson']['Nome']:^16} | {pessoas['Anderson']['Idade']:^5} | {pessoas['Anderson']['Empresa']:^16}")
# Out:
#       Nome       | Idade |     Empresa
# ------------------------------------------
#  Jair Guimarães  |  25   |       UPE
# Gabriel Oliveira |  25   |     Musashi
# Anderson de Deus |  39   |    Aeroporto

# %% [markdown]
# Repare que há muita repetição de código. Para evitar isso, mais adiante no curso veremos como criar *loops* (laços) de repetição.

# %% [markdown]
# Para saber mais, [veja a documentação das f-strings](https://docs.python.org/3/reference/lexical_analysis.html#f-strings).
