# %%
import speech_recognition as sr

# %%
# Reconhecedor:

rec = sr.Recognizer()

# %%
with sr.AudioFile("audio.wav") as arquivo_audio:
    audio = rec.record(arquivo_audio)
    texto = rec.recognize_amazon(audio, language="pr-BR")
    print(texto)
